# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13652\4080736814.py in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as ax

df=pd.read_csv("C:\\Users\\athar\\Documents\\data science\\data_for_lr.csv")

# %%
df
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       700 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 11.1 KB

# %%
df.x
# Out:
# 0      24.0
# 1      50.0
# 2      15.0
# 3      38.0
# 4      87.0
#        ...
# 695    58.0
# 696    93.0
# 697    82.0
# 698    66.0
# 699    97.0
# Name: x, Length: 700, dtype: float64

# %%
df.isnull()
# Out:
#          x      y
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 695  False  False
# 696  False  False
# 697  False  False
# 698  False  False
# 699  False  False
#
# [700 rows x 2 columns]

# %%
data=df.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 699 entries, 0 to 699
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       699 non-null    float64
#  1   y       699 non-null    float64
# dtypes: float64(2)
# memory usage: 16.4 KB

# %%
data.x
# Out:
# 0      24.0
# 1      50.0
# 2      15.0
# 3      38.0
# 4      87.0
#        ...
# 695    58.0
# 696    93.0
# 697    82.0
# 698    66.0
# 699    97.0
# Name: x, Length: 699, dtype: float64

# %%
#training data
train_input=np.array(data.x[:500]).reshape([500,1])

#train_output
train_output=np.array(data.y[:500]).reshape([500,1])
train_output
# Out:
# array([[ 21.54945196],
#        [ 47.46446305],
#        [ 17.21865634],
#        [ 36.58639803],
#        [ 87.28898389],
#        [ 32.46387493],
#        [ 10.78089683],
#        [ 80.7633986 ],
#        [ 24.61215147],
#        [  6.96331907],
#        [ 11.23757338],
#        [ 13.53290206],
#        [ 24.60323899],
#        [ 39.40049976],
#        [ 48.43753838],
#        [ 61.69900319],
#        [ 26.92832418],
#        [ 70.4052055 ],
#        [ 29.34092408],
#        [ 25.30895192],
#        [ 69.02934339],
#        [ 84.99484703],
#        [ 57.04310305],
#        [ 50.5921991 ],
#        [ 83.02772202],
#        [ 57.05752706],
#        [ 47.95883341],
#        [ 24.34226432],
#        [ 94.68488281],
#        [ 48.03970696],
#        [  7.08132338],
#        [ 21.99239907],
#        [ 42.33151664],
#        [  0.32908944],
#        [ 61.92303698],
#        [ 91.17716423],
#        [ 39.45358014],
#        [  5.99606961],
#        [ 22.59015942],
#        [ 61.18044414],
# ...

# %%
train_input
# Out:
# array([[ 24.],
#        [ 50.],
#        [ 15.],
#        [ 38.],
#        [ 87.],
#        [ 36.],
#        [ 12.],
#        [ 81.],
#        [ 25.],
#        [  5.],
#        [ 16.],
#        [ 16.],
#        [ 24.],
#        [ 39.],
#        [ 54.],
#        [ 60.],
#        [ 26.],
#        [ 73.],
#        [ 29.],
#        [ 31.],
#        [ 68.],
#        [ 87.],
#        [ 58.],
#        [ 54.],
#        [ 84.],
#        [ 58.],
#        [ 49.],
#        [ 20.],
#        [ 90.],
#        [ 48.],
#        [  4.],
#        [ 25.],
#        [ 42.],
#        [  0.],
#        [ 60.],
#        [ 93.],
#        [ 39.],
#        [  7.],
#        [ 21.],
#        [ 68.],
#        [ 84.],
#        [  0.],
#        [ 58.],
#        [ 19.],
#        [ 36.],
#        [ 19.],
#        [ 59.],
#        [ 51.],
#        [ 19.],
#        [ 33.],
#        [ 85.],
#        [ 44.],
#        [  5.],
#        [ 59.],
#        [ 14.],
#        [  9.],
#        [ 75.],
#        [ 69.],
# ...

# %%
#test data
test_input=np.array(data.x[500:700]).reshape([199,1])

#test_output
test_output=np.array(data.y[500:700]).reshape([199,1])
test_output
# Out:
# array([[  7.68202459],
#        [ 61.01858089],
#        [ 53.60562216],
#        [ 94.47728801],
#        [ 27.9645947 ],
#        [ 62.55662585],
#        [  1.40625441],
#        [101.7003412 ],
#        [ 13.84973988],
#        [ 28.99769315],
#        [ 99.04315693],
#        [ 15.56135514],
#        [ 24.63528393],
#        [ 53.98393374],
#        [ 42.91449728],
#        [ 74.29662112],
#        [ 91.17012883],
#        [ 49.42440876],
#        [ 82.47683519],
#        [ 56.15303953],
#        [ 37.17063131],
#        [ 46.36928662],
#        [ 97.02383456],
#        [ 40.83182104],
#        [ 24.08498313],
#        [ 41.14386358],
#        [ 21.97388066],
#        [100.740897  ],
#        [ 61.19971596],
#        [ 74.39517002],
#        [ 69.04377173],
#        [ 56.68718792],
#        [  5.86039171],
#        [ 55.72021356],
#        [ 79.22021816],
#        [ 86.30177517],
#        [ 25.26971886],
#        [ 36.33294447],
#        [ 27.65574228],
#        [ 94.79690531],
# ...

# %%
#linear Regression
#step 1-forward propogration

def forward_propogration(train_input,parameters):
    m=parameters['m']
    c=parameters['c']
    
    predictions=np.multiply(m,train_input)+c
    
    
    return predictions

# %%
#step-2 Cost Functions
#summession(1/2n*(yi-f(x))^2

def cost_function(predictions,train_output):
    cost=np.mean((train_output-predictions)**2)*0.5
    
    return cost

# %%
#step-3 gradient descent for backpropagatid
#df=summm(f(x)-y)
#dm=df*x
#dc=df*1

# %%
def backward_propagation(train_input,train_output,predictions):
    derivaties=dict()
    df=(predictions-train_output)
    dm=np.mean(np.multiply(df,train_input))
    dc=np.mean(df)
    derivaties['dm']=dm
    derivaties['dc']=dc
    
    return derivaties

# %%
#updated parameters
#m=m-(learning_rate*dm)
#c=c-(learning_rate*dc)

# %%
def update_parameters(parameters,learning_rate,derivaties):
    parameters['m']=parameters['m']-learning_rate*derivaties['dm'] 
    parameters['c']=parameters['c']-learning_rate*derivaties['dc'] 
    return parameters

# %%
#model training

def train(train_input,train_output,learning_rate,iters):
    parameters=dict()
    parameters['m']=np.random.uniform(0,1)
    parameters['c']=np.random.uniform(0,1)
    
    plt.figure()
    
    loss=list()
    
    for i in range(iters):
        predictions=forward_propogration(train_input,parameters)
        cost=cost_function(predictions,train_output)
        loss.append(cost)
        
        print("Iteration {} lostt {}".format(i,cost))
        
        #plot
        fig,ax=plt.subplots()
        ax.plot(train_input,train_output,"+",label="original")
        ax.plot(train_input,predictions,"*",label="training")
        
        
        legend=ax.legend()
        
        plt.plot(train_input,train_output,"+",label="original")
        plt.plot(train_input,predictions,"*",label="training")
        
        plt.show()
        
        derivaties=backward_propagation(train_input,train_output,predictions)
        parameters=update_parameters(parameters,learning_rate,derivaties)
        
    return parameters,loss

# %%
parameters,loss=train(train_input,train_output,0.0001,20)
print("parameters {} lost{}".format(parameters,loss))
# Out:
# Iteration 0 lostt 59.741030786653916
# Iteration 1 lostt 29.285989590806597
# Iteration 2 lostt 15.468501390508496
# Iteration 3 lostt 9.199489412845145
# Iteration 4 lostt 6.355229458509225
# Iteration 5 lostt 5.064783290668125
# Iteration 6 lostt 4.479304158942554
# Iteration 7 lostt 4.213669352467804
# Iteration 8 lostt 4.093148270746748
# Iteration 9 lostt 4.0384654467950245
# Iteration 10 lostt 4.01365351343305
# Iteration 11 lostt 4.002394036332506
# Iteration 12 lostt 3.997283323763647
# Iteration 13 lostt 3.9949623125880582
# Iteration 14 lostt 3.9939069921391948
# Iteration 15 lostt 3.9934259170895823
# Iteration 16 lostt 3.993205377928266
# Iteration 17 lostt 3.9931030443026447
# Iteration 18 lostt 3.9930543407740844
# Iteration 19 lostt 3.9930299693945455
# ...

# %%
plt.plot(loss)

# %%
test_prediction=test_input*parameters['m']+parameters['c']

# %%
plt.plot(test_input,test_prediction,'+')
plt.plot(test_input,test_output,'.')
plt.show()

# %%
#cost functions

cost=cost_function(test_output,test_prediction)
print(cost)
# Out:
# 4.008343262390867

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model=LinearRegression()
lr_model.fit(train_input,train_output)
# Out:
# LinearRegression()

# %%
lr_model.coef_
# Out:
# array([[1.0009993]])

# %%
lr_model.intercept_
# Out:
# array([-0.23603461])

# %%
#Predictions

test_predictions=lr_model.predict(test_input)

# %%
plt.plot(test_input,test_predictions,'+',color='green')
plt.plot(test_input,test_output,'*',color='red')
plt.xlabel("Input")
plt.ylabel("Output")
plt.title("Performance testing")
plt.show()
